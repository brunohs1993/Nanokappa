# %%
import numpy as np
import scipy.constants as ct
import matplotlib.pyplot as plt

# %%
omega = 1e14

T = np.arange(1,500)
n = 1/(np.exp(ct.hbar*omega/(ct.k*T) ) - 1 )
E1 = ct.hbar*omega*(n+0.5)

E2 = ct.k*T

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(T, E1, color='blue')
ax.plot(T, E2, color = 'red')

plt.yscale('linear')
