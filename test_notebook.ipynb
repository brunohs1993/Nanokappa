# %%
# %matplotlib ipympl

import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as ct
from scipy.interpolate import interp1d
import trimesh as tm
import trimesh.ray.ray_pyembree
import h5py
import pyiron.vasp.structure
from mpl_toolkits.mplot3d import Axes3D
import time
import seaborn as sns

np.set_printoptions(precision=3)

print('done importing modules!')
# Out:
# done importing modules!

# %%
mesh = tm.load('std_geo/cuboid.stl') # shape2S2

# manipulating mesh
mesh.vertices /= 2
mesh.rezero()
mesh.vertices = mesh.vertices*np.array([5, 1, 1])   # resizing cube
limits = mesh.bounds

phonons = h5py.File('kappa-m20206.hdf5', 'r')                   # phonon properties
crystal = pyiron.vasp.structure.read_atoms('POSCAR-unitcell')   # crystal properties

# crystal.plot3d()
# mesh.show()

# %%
# PHONON MODES COMPUTATION

crystal_omega = np.array(phonons['frequency'])*2*ct.pi*1e12

n_of_qpoints = np.array(phonons['frequency']).shape[0]
n_of_branches = np.array(phonons['frequency']).shape[1]
n_of_modes = n_of_branches*n_of_qpoints

T_c = 1    # cold temperature
T_h = 500   # hot temperature
T_step = 1 # step of temperature array

crystal_temperature = np.arange(T_c, T_h+2*T_step, T_step)
crystal_energy      = np.zeros(crystal_temperature.shape)

for i in range(crystal_temperature.shape[0]):
    T = crystal_temperature[i]
    crystal_occupation = 1/(np.exp(ct.hbar*crystal_omega/(ct.k*T))-1)
    
    E = ct.hbar*crystal_omega*(0.5 + crystal_occupation)
    crystal_energy[i] = E.sum()/n_of_modes   # average energy per particle at correspondent temperature

energy_function = interp1d(crystal_temperature, crystal_energy) # average energy per particle function e = f(T)
temperature_function = interp1d(crystal_energy, crystal_temperature) # temperature function e = f(T)


# COMPUTE PRIORITIES

matrix = np.abs(crystal_omega)

rank = matrix.argsort(axis = None).argsort().reshape(matrix.shape)

fig = plt.figure(figsize = (15, 5))
ax = fig.add_subplot(121)
ax = sns.heatmap(crystal_omega, cmap = 'viridis')
ax.invert_yaxis()
ax = fig.add_subplot(122)
ax = sns.heatmap(rank,  cmap = 'viridis')
ax.invert_yaxis()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# DIVIDE PARTICLES FOR EACH MODE

n_of_particles = int(1e6)

part_p_mode = np.ceil(n_of_particles/n_of_modes)    # particles per mode

surplus = int(part_p_mode*n_of_modes-n_of_particles)    # excess of particles due to rounding

surplus_modes = np.where(rank.reshape(-1)>(rank.max()-surplus))[0]

ppm_array = (np.ones(n_of_modes)*part_p_mode).astype(int)

ppm_array[surplus_modes] -= 1                                   # number of particles per mode without excess

# %%
# PARTICLE GENERATION (LAURENT'S METHOD)

start = time.time()

modes     = np.zeros( (1, 2) )
positions = np.zeros( (1, 3) )

for i in range(n_of_qpoints):
    for j in range(n_of_branches):

        index = int(i*n_of_branches+j)

        buffer_modes      = np.ones( (ppm_array[index], 2) )
        buffer_modes[:,0] *= i                         
        buffer_modes[:,1] *= j

        buffer_positions = np.random.rand(buffer_modes.shape[0], 3)*(limits[1,:] - limits[0,:]) + limits[0,:]
        in_points = mesh.contains(buffer_positions)
        buffer_positions = np.delete(buffer_positions, ~in_points, axis=0)

        new_points = np.random.rand(buffer_modes.shape[0]-buffer_positions.shape[0], 3)*(limits[1,:] - limits[0,:]) + limits[0,:]
        in_points = mesh.contains(new_points)

        buffer_positions = np.row_stack( (buffer_positions, new_points[in_points]) )

        while np.any(~in_points):
            new_points = np.random.rand(buffer_modes.shape[0]-buffer_positions.shape[0], 3)*(limits[1,:] - limits[0,:]) + limits[0,:]

            in_points = mesh.contains(new_points)

            buffer_positions = np.row_stack( (buffer_positions, new_points[in_points]) )

        modes = np.row_stack( (modes, buffer_modes) )

        positions = np.row_stack( (positions, buffer_positions) )

        print('Mode {:>4d} of {:>4d}, Q-point {:>3d}, branch {:>2d}: {:>10d} particles.'.format(index+1, n_of_modes, i, j, ppm_array[index]))

modes     = np.delete(modes, 0, axis = 0).astype(int)
positions = np.delete(positions, 0, axis = 0)

end = time.time()

print('Particles generated! Time: {:.3f} s'.format(end-start))
# Out:
# Mode    1 of 3168, Q-point   0, branch  0:         32 particles.
# Mode    2 of 3168, Q-point   0, branch  1:         32 particles.
# Mode    3 of 3168, Q-point   0, branch  2:         32 particles.
# Mode    4 of 3168, Q-point   0, branch  3:         32 particles.
# Mode    5 of 3168, Q-point   0, branch  4:         32 particles.
# Mode    6 of 3168, Q-point   0, branch  5:         32 particles.
# Mode    7 of 3168, Q-point   0, branch  6:         32 particles.
# Mode    8 of 3168, Q-point   0, branch  7:         32 particles.
# Mode    9 of 3168, Q-point   0, branch  8:         32 particles.
# Mode   10 of 3168, Q-point   0, branch  9:         32 particles.
# Mode   11 of 3168, Q-point   0, branch 10:         31 particles.
# Mode   12 of 3168, Q-point   0, branch 11:         31 particles.
# Mode   13 of 3168, Q-point   0, branch 12:         31 particles.
# Mode   14 of 3168, Q-point   0, branch 13:         31 particles.
# Mode   15 of 3168, Q-point   0, branch 14:         31 particles.
# Mode   16 of 3168, Q-point   0, branch 15:         31 particles.
# Mode   17 of 3168, Q-point   0, branch 16:         31 particles.
# Mode   18 of 3168, Q-point   0, branch 17:         31 particles.
# Mode   19 of 3168, Q-point   1, branch  0:         32 particles.
# Mode   20 of 3168, Q-point   1, branch  1:         32 particles.
# Mode   21 of 3168, Q-point   1, branch  2:         32 particles.
# Mode   22 of 3168, Q-point   1, branch  3:         32 particles.
# Mode   23 of 3168, Q-point   1, branch  4:         32 particles.
# Mode   24 of 3168, Q-point   1, branch  5:         32 particles.
# Mode   25 of 3168, Q-point   1, branch  6:         32 particles.
# Mode   26 of 3168, Q-point   1, branch  7:         32 particles.
# Mode   27 of 3168, Q-point   1, branch  8:         32 particles.
# Mode   28 of 3168, Q-point   1, branch  9:         32 particles.
# Mode   29 of 3168, Q-point   1, branch 10:         31 particles.
# Mode   30 of 3168, Q-point   1, branch 11:         31 particles.
# Mode   31 of 3168, Q-point   1, branch 12:         31 particles.
# Mode   32 of 3168, Q-point   1, branch 13:         31 particles.
# Mode   33 of 3168, Q-point   1, branch 14:         31 particles.
# Mode   34 of 3168, Q-point   1, branch 15:         31 particles.
# Mode   35 of 3168, Q-point   1, branch 16:         31 particles.
# Mode   36 of 3168, Q-point   1, branch 17:         31 particles.
# Mode   37 of 3168, Q-point   2, branch  0:         32 particles.
# Mode   38 of 3168, Q-point   2, branch  1:         32 particles.
# Mode   39 of 3168, Q-point   2, branch  2:         32 particles.
# Mode   40 of 3168, Q-point   2, branch  3:         32 particles.
# Mode   41 of 3168, Q-point   2, branch  4:         32 particles.
# Mode   42 of 3168, Q-point   2, branch  5:         32 particles.
# Mode   43 of 3168, Q-point   2, branch  6:         32 particles.
# Mode   44 of 3168, Q-point   2, branch  7:         32 particles.
# Mode   45 of 3168, Q-point   2, branch  8:         32 particles.
# Mode   46 of 3168, Q-point   2, branch  9:         32 particles.
# Mode   47 of 3168, Q-point   2, branch 10:         31 particles.
# Mode   48 of 3168, Q-point   2, branch 11:         31 particles.
# Mode   49 of 3168, Q-point   2, branch 12:         31 particles.
# Mode   50 of 3168, Q-point   2, branch 13:         31 particles.
# Mode   51 of 3168, Q-point   2, branch 14:         31 particles.
# Mode   52 of 3168, Q-point   2, branch 15:         31 particles.
# Mode   53 of 3168, Q-point   2, branch 16:         31 particles.
# Mode   54 of 3168, Q-point   2, branch 17:         31 particles.
# Mode   55 of 3168, Q-point   3, branch  0:         32 particles.
# Mode   56 of 3168, Q-point   3, branch  1:         32 particles.
# Mode   57 of 3168, Q-point   3, branch  2:         32 particles.
# Mode   58 of 3168, Q-point   3, branch  3:         32 particles.
# Mode   59 of 3168, Q-point   3, branch  4:         32 particles.
# Mode   60 of 3168, Q-point   3, branch  5:         32 particles.
# Mode   61 of 3168, Q-point   3, branch  6:         32 particles.
# Mode   62 of 3168, Q-point   3, branch  7:         32 particles.
# Mode   63 of 3168, Q-point   3, branch  8:         32 particles.
# Mode   64 of 3168, Q-point   3, branch  9:         32 particles.
# Mode   65 of 3168, Q-point   3, branch 10:         31 particles.
# Mode   66 of 3168, Q-point   3, branch 11:         31 particles.
# Mode   67 of 3168, Q-point   3, branch 12:         31 particles.
# Mode   68 of 3168, Q-point   3, branch 13:         31 particles.
# Mode   69 of 3168, Q-point   3, branch 14:         31 particles.
# Mode   70 of 3168, Q-point   3, branch 15:         31 particles.
# Mode   71 of 3168, Q-point   3, branch 16:         31 particles.
# Mode   72 of 3168, Q-point   3, branch 17:         31 particles.
# Mode   73 of 3168, Q-point   4, branch  0:         32 particles.
# Mode   74 of 3168, Q-point   4, branch  1:         32 particles.
# Mode   75 of 3168, Q-point   4, branch  2:         32 particles.
# Mode   76 of 3168, Q-point   4, branch  3:         32 particles.
# Mode   77 of 3168, Q-point   4, branch  4:         32 particles.
# Mode   78 of 3168, Q-point   4, branch  5:         32 particles.
# Mode   79 of 3168, Q-point   4, branch  6:         32 particles.
# Mode   80 of 3168, Q-point   4, branch  7:         32 particles.
# Mode   81 of 3168, Q-point   4, branch  8:         32 particles.
# Mode   82 of 3168, Q-point   4, branch  9:         32 particles.
# Mode   83 of 3168, Q-point   4, branch 10:         31 particles.
# Mode   84 of 3168, Q-point   4, branch 11:         31 particles.
# Mode   85 of 3168, Q-point   4, branch 12:         31 particles.
# Mode   86 of 3168, Q-point   4, branch 13:         31 particles.
# Mode   87 of 3168, Q-point   4, branch 14:         31 particles.
# Mode   88 of 3168, Q-point   4, branch 15:         31 particles.
# Mode   89 of 3168, Q-point   4, branch 16:         31 particles.
# Mode   90 of 3168, Q-point   4, branch 17:         31 particles.
# Mode   91 of 3168, Q-point   5, branch  0:         32 particles.
# Mode   92 of 3168, Q-point   5, branch  1:         32 particles.
# Mode   93 of 3168, Q-point   5, branch  2:         32 particles.
# Mode   94 of 3168, Q-point   5, branch  3:         32 particles.
# Mode   95 of 3168, Q-point   5, branch  4:         32 particles.
# Mode   96 of 3168, Q-point   5, branch  5:         32 particles.
# Mode   97 of 3168, Q-point   5, branch  6:         32 particles.
# Mode   98 of 3168, Q-point   5, branch  7:         32 particles.
# Mode   99 of 3168, Q-point   5, branch  8:         32 particles.
# Mode  100 of 3168, Q-point   5, branch  9:         32 particles.
# Mode  101 of 3168, Q-point   5, branch 10:         32 particles.
# Mode  102 of 3168, Q-point   5, branch 11:         32 particles.
# Mode  103 of 3168, Q-point   5, branch 12:         31 particles.
# Mode  104 of 3168, Q-point   5, branch 13:         31 particles.
# Mode  105 of 3168, Q-point   5, branch 14:         31 particles.
# Mode  106 of 3168, Q-point   5, branch 15:         31 particles.
# Mode  107 of 3168, Q-point   5, branch 16:         31 particles.
# Mode  108 of 3168, Q-point   5, branch 17:         31 particles.
# Mode  109 of 3168, Q-point   6, branch  0:         32 particles.
# Mode  110 of 3168, Q-point   6, branch  1:         32 particles.
# Mode  111 of 3168, Q-point   6, branch  2:         32 particles.
# Mode  112 of 3168, Q-point   6, branch  3:         32 particles.
# Mode  113 of 3168, Q-point   6, branch  4:         32 particles.
# Mode  114 of 3168, Q-point   6, branch  5:         32 particles.
# Mode  115 of 3168, Q-point   6, branch  6:         32 particles.
# Mode  116 of 3168, Q-point   6, branch  7:         32 particles.
# Mode  117 of 3168, Q-point   6, branch  8:         32 particles.
# Mode  118 of 3168, Q-point   6, branch  9:         32 particles.
# Mode  119 of 3168, Q-point   6, branch 10:         32 particles.
# Mode  120 of 3168, Q-point   6, branch 11:         31 particles.
# Mode  121 of 3168, Q-point   6, branch 12:         31 particles.
# Mode  122 of 3168, Q-point   6, branch 13:         31 particles.
# Mode  123 of 3168, Q-point   6, branch 14:         31 particles.
# Mode  124 of 3168, Q-point   6, branch 15:         31 particles.
# Mode  125 of 3168, Q-point   6, branch 16:         31 particles.
# Mode  126 of 3168, Q-point   6, branch 17:         31 particles.
# Mode  127 of 3168, Q-point   7, branch  0:         32 particles.
# Mode  128 of 3168, Q-point   7, branch  1:         32 particles.
# Mode  129 of 3168, Q-point   7, branch  2:         32 particles.
# Mode  130 of 3168, Q-point   7, branch  3:         32 particles.
# Mode  131 of 3168, Q-point   7, branch  4:         32 particles.
# Mode  132 of 3168, Q-point   7, branch  5:         32 particles.
# Mode  133 of 3168, Q-point   7, branch  6:         32 particles.
# Mode  134 of 3168, Q-point   7, branch  7:         32 particles.
# Mode  135 of 3168, Q-point   7, branch  8:         32 particles.
# Mode  136 of 3168, Q-point   7, branch  9:         32 particles.
# Mode  137 of 3168, Q-point   7, branch 10:         31 particles.
# Mode  138 of 3168, Q-point   7, branch 11:         31 particles.
# Mode  139 of 3168, Q-point   7, branch 12:         31 particles.
# Mode  140 of 3168, Q-point   7, branch 13:         31 particles.
# Mode  141 of 3168, Q-point   7, branch 14:         31 particles.
# Mode  142 of 3168, Q-point   7, branch 15:         31 particles.
# Mode  143 of 3168, Q-point   7, branch 16:         31 particles.
# Mode  144 of 3168, Q-point   7, branch 17:         31 particles.
# Mode  145 of 3168, Q-point   8, branch  0:         32 particles.
# Mode  146 of 3168, Q-point   8, branch  1:         32 particles.
# Mode  147 of 3168, Q-point   8, branch  2:         32 particles.
# Mode  148 of 3168, Q-point   8, branch  3:         32 particles.
# Mode  149 of 3168, Q-point   8, branch  4:         32 particles.
# Mode  150 of 3168, Q-point   8, branch  5:         32 particles.
# Mode  151 of 3168, Q-point   8, branch  6:         32 particles.
# Mode  152 of 3168, Q-point   8, branch  7:         32 particles.
# Mode  153 of 3168, Q-point   8, branch  8:         32 particles.
# Mode  154 of 3168, Q-point   8, branch  9:         32 particles.
# Mode  155 of 3168, Q-point   8, branch 10:         31 particles.
# Mode  156 of 3168, Q-point   8, branch 11:         31 particles.
# Mode  157 of 3168, Q-point   8, branch 12:         31 particles.
# Mode  158 of 3168, Q-point   8, branch 13:         31 particles.
# Mode  159 of 3168, Q-point   8, branch 14:         31 particles.
# Mode  160 of 3168, Q-point   8, branch 15:         31 particles.
# Mode  161 of 3168, Q-point   8, branch 16:         31 particles.
# Mode  162 of 3168, Q-point   8, branch 17:         31 particles.
# Mode  163 of 3168, Q-point   9, branch  0:         32 particles.
# Mode  164 of 3168, Q-point   9, branch  1:         32 particles.
# Mode  165 of 3168, Q-point   9, branch  2:         32 particles.
# Mode  166 of 3168, Q-point   9, branch  3:         32 particles.
# Mode  167 of 3168, Q-point   9, branch  4:         32 particles.
# Mode  168 of 3168, Q-point   9, branch  5:         32 particles.
# Mode  169 of 3168, Q-point   9, branch  6:         32 particles.
# Mode  170 of 3168, Q-point   9, branch  7:         32 particles.
# Mode  171 of 3168, Q-point   9, branch  8:         32 particles.
# Mode  172 of 3168, Q-point   9, branch  9:         32 particles.
# Mode  173 of 3168, Q-point   9, branch 10:         31 particles.
# Mode  174 of 3168, Q-point   9, branch 11:         31 particles.
# Mode  175 of 3168, Q-point   9, branch 12:         31 particles.
# Mode  176 of 3168, Q-point   9, branch 13:         31 particles.
# Mode  177 of 3168, Q-point   9, branch 14:         31 particles.
# Mode  178 of 3168, Q-point   9, branch 15:         31 particles.
# Mode  179 of 3168, Q-point   9, branch 16:         31 particles.
# Mode  180 of 3168, Q-point   9, branch 17:         31 particles.
# Mode  181 of 3168, Q-point  10, branch  0:         32 particles.
# Mode  182 of 3168, Q-point  10, branch  1:         32 particles.
# Mode  183 of 3168, Q-point  10, branch  2:         32 particles.
# Mode  184 of 3168, Q-point  10, branch  3:         32 particles.
# Mode  185 of 3168, Q-point  10, branch  4:         32 particles.
# Mode  186 of 3168, Q-point  10, branch  5:         32 particles.
# Mode  187 of 3168, Q-point  10, branch  6:         32 particles.
# Mode  188 of 3168, Q-point  10, branch  7:         32 particles.
# Mode  189 of 3168, Q-point  10, branch  8:         32 particles.
# Mode  190 of 3168, Q-point  10, branch  9:         32 particles.
# Mode  191 of 3168, Q-point  10, branch 10:         31 particles.
# Mode  192 of 3168, Q-point  10, branch 11:         31 particles.
# Mode  193 of 3168, Q-point  10, branch 12:         31 particles.
# Mode  194 of 3168, Q-point  10, branch 13:         31 particles.
# Mode  195 of 3168, Q-point  10, branch 14:         31 particles.
# Mode  196 of 3168, Q-point  10, branch 15:         31 particles.
# Mode  197 of 3168, Q-point  10, branch 16:         31 particles.
# Mode  198 of 3168, Q-point  10, branch 17:         31 particles.
# Mode  199 of 3168, Q-point  11, branch  0:         32 particles.
# Mode  200 of 3168, Q-point  11, branch  1:         32 particles.
# Mode  201 of 3168, Q-point  11, branch  2:         32 particles.
# Mode  202 of 3168, Q-point  11, branch  3:         32 particles.
# Mode  203 of 3168, Q-point  11, branch  4:         32 particles.
# Mode  204 of 3168, Q-point  11, branch  5:         32 particles.
# Mode  205 of 3168, Q-point  11, branch  6:         32 particles.
# Mode  206 of 3168, Q-point  11, branch  7:         32 particles.
# Mode  207 of 3168, Q-point  11, branch  8:         32 particles.
# Mode  208 of 3168, Q-point  11, branch  9:         32 particles.
# Mode  209 of 3168, Q-point  11, branch 10:         31 particles.
# Mode  210 of 3168, Q-point  11, branch 11:         31 particles.
# Mode  211 of 3168, Q-point  11, branch 12:         31 particles.
# Mode  212 of 3168, Q-point  11, branch 13:         31 particles.
# Mode  213 of 3168, Q-point  11, branch 14:         31 particles.
# Mode  214 of 3168, Q-point  11, branch 15:         31 particles.
# Mode  215 of 3168, Q-point  11, branch 16:         31 particles.
# Mode  216 of 3168, Q-point  11, branch 17:         31 particles.
# Mode  217 of 3168, Q-point  12, branch  0:         32 particles.
# Mode  218 of 3168, Q-point  12, branch  1:         32 particles.
# Mode  219 of 3168, Q-point  12, branch  2:         32 particles.
# Mode  220 of 3168, Q-point  12, branch  3:         32 particles.
# Mode  221 of 3168, Q-point  12, branch  4:         32 particles.
# Mode  222 of 3168, Q-point  12, branch  5:         32 particles.
# Mode  223 of 3168, Q-point  12, branch  6:         32 particles.
# Mode  224 of 3168, Q-point  12, branch  7:         32 particles.
# Mode  225 of 3168, Q-point  12, branch  8:         32 particles.
# Mode  226 of 3168, Q-point  12, branch  9:         32 particles.
# Mode  227 of 3168, Q-point  12, branch 10:         31 particles.
# Mode  228 of 3168, Q-point  12, branch 11:         31 particles.
# Mode  229 of 3168, Q-point  12, branch 12:         31 particles.
# Mode  230 of 3168, Q-point  12, branch 13:         31 particles.
# Mode  231 of 3168, Q-point  12, branch 14:         31 particles.
# Mode  232 of 3168, Q-point  12, branch 15:         31 particles.
# Mode  233 of 3168, Q-point  12, branch 16:         31 particles.
# Mode  234 of 3168, Q-point  12, branch 17:         31 particles.
# Mode  235 of 3168, Q-point  13, branch  0:         32 particles.
# Mode  236 of 3168, Q-point  13, branch  1:         32 particles.
# Mode  237 of 3168, Q-point  13, branch  2:         32 particles.
# Mode  238 of 3168, Q-point  13, branch  3:         32 particles.
# Mode  239 of 3168, Q-point  13, branch  4:         32 particles.
# Mode  240 of 3168, Q-point  13, branch  5:         32 particles.
# Mode  241 of 3168, Q-point  13, branch  6:         32 particles.
# Mode  242 of 3168, Q-point  13, branch  7:         32 particles.
# Mode  243 of 3168, Q-point  13, branch  8:         32 particles.
# Mode  244 of 3168, Q-point  13, branch  9:         32 particles.
# Mode  245 of 3168, Q-point  13, branch 10:         31 particles.
# Mode  246 of 3168, Q-point  13, branch 11:         31 particles.
# Mode  247 of 3168, Q-point  13, branch 12:         31 particles.
# Mode  248 of 3168, Q-point  13, branch 13:         31 particles.
# Mode  249 of 3168, Q-point  13, branch 14:         31 particles.
# Mode  250 of 3168, Q-point  13, branch 15:         31 particles.
# Mode  251 of 3168, Q-point  13, branch 16:         31 particles.
# Mode  252 of 3168, Q-point  13, branch 17:         31 particles.
# Mode  253 of 3168, Q-point  14, branch  0:         32 particles.
# Mode  254 of 3168, Q-point  14, branch  1:         32 particles.
# Mode  255 of 3168, Q-point  14, branch  2:         32 particles.
# Mode  256 of 3168, Q-point  14, branch  3:         32 particles.
# Mode  257 of 3168, Q-point  14, branch  4:         32 particles.
# Mode  258 of 3168, Q-point  14, branch  5:         32 particles.
# Mode  259 of 3168, Q-point  14, branch  6:         32 particles.
# Mode  260 of 3168, Q-point  14, branch  7:         32 particles.
# Mode  261 of 3168, Q-point  14, branch  8:         32 particles.
# Mode  262 of 3168, Q-point  14, branch  9:         32 particles.
# Mode  263 of 3168, Q-point  14, branch 10:         32 particles.
# Mode  264 of 3168, Q-point  14, branch 11:         32 particles.
# Mode  265 of 3168, Q-point  14, branch 12:         31 particles.
# Mode  266 of 3168, Q-point  14, branch 13:         31 particles.
# Mode  267 of 3168, Q-point  14, branch 14:         31 particles.
# Mode  268 of 3168, Q-point  14, branch 15:         31 particles.
# Mode  269 of 3168, Q-point  14, branch 16:         31 particles.
# Mode  270 of 3168, Q-point  14, branch 17:         31 particles.
# Mode  271 of 3168, Q-point  15, branch  0:         32 particles.
# Mode  272 of 3168, Q-point  15, branch  1:         32 particles.
# Mode  273 of 3168, Q-point  15, branch  2:         32 particles.
# Mode  274 of 3168, Q-point  15, branch  3:         32 particles.
# Mode  275 of 3168, Q-point  15, branch  4:         32 particles.
# Mode  276 of 3168, Q-point  15, branch  5:         32 particles.
# Mode  277 of 3168, Q-point  15, branch  6:         32 particles.
# Mode  278 of 3168, Q-point  15, branch  7:         32 particles.
# Mode  279 of 3168, Q-point  15, branch  8:         32 particles.
# Mode  280 of 3168, Q-point  15, branch  9:         32 particles.
# Mode  281 of 3168, Q-point  15, branch 10:         32 particles.
# Mode  282 of 3168, Q-point  15, branch 11:         32 particles.
# Mode  283 of 3168, Q-point  15, branch 12:         31 particles.
# Mode  284 of 3168, Q-point  15, branch 13:         31 particles.
# Mode  285 of 3168, Q-point  15, branch 14:         31 particles.
# Mode  286 of 3168, Q-point  15, branch 15:         31 particles.
# Mode  287 of 3168, Q-point  15, branch 16:         31 particles.
# Mode  288 of 3168, Q-point  15, branch 17:         31 particles.
# Mode  289 of 3168, Q-point  16, branch  0:         32 particles.
# Mode  290 of 3168, Q-point  16, branch  1:         32 particles.
# Mode  291 of 3168, Q-point  16, branch  2:         32 particles.
# Mode  292 of 3168, Q-point  16, branch  3:         32 particles.
# Mode  293 of 3168, Q-point  16, branch  4:         32 particles.
# Mode  294 of 3168, Q-point  16, branch  5:         32 particles.
# Mode  295 of 3168, Q-point  16, branch  6:         32 particles.
# Mode  296 of 3168, Q-point  16, branch  7:         32 particles.
# Mode  297 of 3168, Q-point  16, branch  8:         32 particles.
# Mode  298 of 3168, Q-point  16, branch  9:         32 particles.
# Mode  299 of 3168, Q-point  16, branch 10:         31 particles.
# Mode  300 of 3168, Q-point  16, branch 11:         31 particles.
# Mode  301 of 3168, Q-point  16, branch 12:         31 particles.
# Mode  302 of 3168, Q-point  16, branch 13:         31 particles.
# Mode  303 of 3168, Q-point  16, branch 14:         31 particles.
# Mode  304 of 3168, Q-point  16, branch 15:         31 particles.
# Mode  305 of 3168, Q-point  16, branch 16:         31 particles.
# Mode  306 of 3168, Q-point  16, branch 17:         31 particles.
# Mode  307 of 3168, Q-point  17, branch  0:         32 particles.
# Mode  308 of 3168, Q-point  17, branch  1:         32 particles.
# Mode  309 of 3168, Q-point  17, branch  2:         32 particles.
# Mode  310 of 3168, Q-point  17, branch  3:         32 particles.
# Mode  311 of 3168, Q-point  17, branch  4:         32 particles.
# Mode  312 of 3168, Q-point  17, branch  5:         32 particles.
# Mode  313 of 3168, Q-point  17, branch  6:         32 particles.
# Mode  314 of 3168, Q-point  17, branch  7:         32 particles.
# Mode  315 of 3168, Q-point  17, branch  8:         32 particles.
# Mode  316 of 3168, Q-point  17, branch  9:         32 particles.
# Mode  317 of 3168, Q-point  17, branch 10:         31 particles.
# Mode  318 of 3168, Q-point  17, branch 11:         31 particles.
# Mode  319 of 3168, Q-point  17, branch 12:         31 particles.
# Mode  320 of 3168, Q-point  17, branch 13:         31 particles.
# Mode  321 of 3168, Q-point  17, branch 14:         31 particles.
# Mode  322 of 3168, Q-point  17, branch 15:         31 particles.
# Mode  323 of 3168, Q-point  17, branch 16:         31 particles.
# Mode  324 of 3168, Q-point  17, branch 17:         31 particles.
# Mode  325 of 3168, Q-point  18, branch  0:         32 particles.
# Mode  326 of 3168, Q-point  18, branch  1:         32 particles.
# Mode  327 of 3168, Q-point  18, branch  2:         32 particles.
# Mode  328 of 3168, Q-point  18, branch  3:         32 particles.
# Mode  329 of 3168, Q-point  18, branch  4:         32 particles.
# Mode  330 of 3168, Q-point  18, branch  5:         32 particles.
# Mode  331 of 3168, Q-point  18, branch  6:         32 particles.
# Mode  332 of 3168, Q-point  18, branch  7:         32 particles.
# Mode  333 of 3168, Q-point  18, branch  8:         32 particles.
# Mode  334 of 3168, Q-point  18, branch  9:         32 particles.
# Mode  335 of 3168, Q-point  18, branch 10:         31 particles.
# Mode  336 of 3168, Q-point  18, branch 11:         31 particles.
# Mode  337 of 3168, Q-point  18, branch 12:         31 particles.
# Mode  338 of 3168, Q-point  18, branch 13:         31 particles.
# Mode  339 of 3168, Q-point  18, branch 14:         31 particles.
# Mode  340 of 3168, Q-point  18, branch 15:         31 particles.
# Mode  341 of 3168, Q-point  18, branch 16:         31 particles.
# Mode  342 of 3168, Q-point  18, branch 17:         31 particles.
# Mode  343 of 3168, Q-point  19, branch  0:         32 particles.
# Mode  344 of 3168, Q-point  19, branch  1:         32 particles.
# Mode  345 of 3168, Q-point  19, branch  2:         32 particles.
# Mode  346 of 3168, Q-point  19, branch  3:         32 particles.
# Mode  347 of 3168, Q-point  19, branch  4:         32 particles.
# Mode  348 of 3168, Q-point  19, branch  5:         32 particles.
# Mode  349 of 3168, Q-point  19, branch  6:         32 particles.
# Mode  350 of 3168, Q-point  19, branch  7:         32 particles.
# Mode  351 of 3168, Q-point  19, branch  8:         32 particles.
# Mode  352 of 3168, Q-point  19, branch  9:         32 particles.
# Mode  353 of 3168, Q-point  19, branch 10:         31 particles.
# Mode  354 of 3168, Q-point  19, branch 11:         31 particles.
# Mode  355 of 3168, Q-point  19, branch 12:         31 particles.
# Mode  356 of 3168, Q-point  19, branch 13:         31 particles.
# Mode  357 of 3168, Q-point  19, branch 14:         31 particles.
# Mode  358 of 3168, Q-point  19, branch 15:         31 particles.
# Mode  359 of 3168, Q-point  19, branch 16:         31 particles.
# Mode  360 of 3168, Q-point  19, branch 17:         31 particles.
# Mode  361 of 3168, Q-point  20, branch  0:         32 particles.
# Mode  362 of 3168, Q-point  20, branch  1:         32 particles.
# Mode  363 of 3168, Q-point  20, branch  2:         32 particles.
# Mode  364 of 3168, Q-point  20, branch  3:         32 particles.
# Mode  365 of 3168, Q-point  20, branch  4:         32 particles.
# Mode  366 of 3168, Q-point  20, branch  5:         32 particles.
# Mode  367 of 3168, Q-point  20, branch  6:         32 particles.
# Mode  368 of 3168, Q-point  20, branch  7:         32 particles.
# Mode  369 of 3168, Q-point  20, branch  8:         32 particles.
# Mode  370 of 3168, Q-point  20, branch  9:         32 particles.
# Mode  371 of 3168, Q-point  20, branch 10:         31 particles.
# Mode  372 of 3168, Q-point  20, branch 11:         31 particles.
# Mode  373 of 3168, Q-point  20, branch 12:         31 particles.
# Mode  374 of 3168, Q-point  20, branch 13:         31 particles.
# Mode  375 of 3168, Q-point  20, branch 14:         31 particles.
# Mode  376 of 3168, Q-point  20, branch 15:         31 particles.
# Mode  377 of 3168, Q-point  20, branch 16:         31 particles.
# Mode  378 of 3168, Q-point  20, branch 17:         31 particles.
# Mode  379 of 3168, Q-point  21, branch  0:         32 particles.
# Mode  380 of 3168, Q-point  21, branch  1:         32 particles.
# Mode  381 of 3168, Q-point  21, branch  2:         32 particles.
# Mode  382 of 3168, Q-point  21, branch  3:         32 particles.
# Mode  383 of 3168, Q-point  21, branch  4:         32 particles.
# Mode  384 of 3168, Q-point  21, branch  5:         32 particles.
# Mode  385 of 3168, Q-point  21, branch  6:         32 particles.
# Mode  386 of 3168, Q-point  21, branch  7:         32 particles.
# Mode  387 of 3168, Q-point  21, branch  8:         32 particles.
# Mode  388 of 3168, Q-point  21, branch  9:         32 particles.
# Mode  389 of 3168, Q-point  21, branch 10:         31 particles.
# Mode  390 of 3168, Q-point  21, branch 11:         31 particles.
# Mode  391 of 3168, Q-point  21, branch 12:         31 particles.
# Mode  392 of 3168, Q-point  21, branch 13:         31 particles.
# Mode  393 of 3168, Q-point  21, branch 14:         31 particles.
# Mode  394 of 3168, Q-point  21, branch 15:         31 particles.
# Mode  395 of 3168, Q-point  21, branch 16:         31 particles.
# Mode  396 of 3168, Q-point  21, branch 17:         31 particles.
# Mode  397 of 3168, Q-point  22, branch  0:         32 particles.
# Mode  398 of 3168, Q-point  22, branch  1:         32 particles.
# Mode  399 of 3168, Q-point  22, branch  2:         32 particles.
# Mode  400 of 3168, Q-point  22, branch  3:         32 particles.
# Mode  401 of 3168, Q-point  22, branch  4:         32 particles.
# Mode  402 of 3168, Q-point  22, branch  5:         32 particles.
# Mode  403 of 3168, Q-point  22, branch  6:         32 particles.
# Mode  404 of 3168, Q-point  22, branch  7:         32 particles.
# Mode  405 of 3168, Q-point  22, branch  8:         32 particles.
# Mode  406 of 3168, Q-point  22, branch  9:         32 particles.
# Mode  407 of 3168, Q-point  22, branch 10:         32 particles.
# Mode  408 of 3168, Q-point  22, branch 11:         31 particles.
# Mode  409 of 3168, Q-point  22, branch 12:         31 particles.
# Mode  410 of 3168, Q-point  22, branch 13:         31 particles.
# Mode  411 of 3168, Q-point  22, branch 14:         31 particles.
# Mode  412 of 3168, Q-point  22, branch 15:         31 particles.
# Mode  413 of 3168, Q-point  22, branch 16:         31 particles.
# Mode  414 of 3168, Q-point  22, branch 17:         31 particles.
# Mode  415 of 3168, Q-point  23, branch  0:         32 particles.
# Mode  416 of 3168, Q-point  23, branch  1:         32 particles.
# Mode  417 of 3168, Q-point  23, branch  2:         32 particles.
# Mode  418 of 3168, Q-point  23, branch  3:         32 particles.
# Mode  419 of 3168, Q-point  23, branch  4:         32 particles.
# Mode  420 of 3168, Q-point  23, branch  5:         32 particles.
# Mode  421 of 3168, Q-point  23, branch  6:         32 particles.
# Mode  422 of 3168, Q-point  23, branch  7:         32 particles.
# Mode  423 of 3168, Q-point  23, branch  8:         32 particles.
# Mode  424 of 3168, Q-point  23, branch  9:         32 particles.
# Mode  425 of 3168, Q-point  23, branch 10:         32 particles.
# Mode  426 of 3168, Q-point  23, branch 11:         31 particles.
# Mode  427 of 3168, Q-point  23, branch 12:         31 particles.
# Mode  428 of 3168, Q-point  23, branch 13:         31 particles.
# Mode  429 of 3168, Q-point  23, branch 14:         31 particles.
# Mode  430 of 3168, Q-point  23, branch 15:         31 particles.
# Mode  431 of 3168, Q-point  23, branch 16:         31 particles.
# Mode  432 of 3168, Q-point  23, branch 17:         31 particles.
# Mode  433 of 3168, Q-point  24, branch  0:         32 particles.
# Mode  434 of 3168, Q-point  24, branch  1:         32 particles.
# Mode  435 of 3168, Q-point  24, branch  2:         32 particles.
# Mode  436 of 3168, Q-point  24, branch  3:         32 particles.
# Mode  437 of 3168, Q-point  24, branch  4:         32 particles.
# Mode  438 of 3168, Q-point  24, branch  5:         32 particles.
# Mode  439 of 3168, Q-point  24, branch  6:         32 particles.
# Mode  440 of 3168, Q-point  24, branch  7:         32 particles.
# Mode  441 of 3168, Q-point  24, branch  8:         32 particles.
# Mode  442 of 3168, Q-point  24, branch  9:         32 particles.
# Mode  443 of 3168, Q-point  24, branch 10:         31 particles.
# Mode  444 of 3168, Q-point  24, branch 11:         31 particles.
# Mode  445 of 3168, Q-point  24, branch 12:         31 particles.
# Mode  446 of 3168, Q-point  24, branch 13:         31 particles.
# Mode  447 of 3168, Q-point  24, branch 14:         31 particles.
# Mode  448 of 3168, Q-point  24, branch 15:         31 particles.
# Mode  449 of 3168, Q-point  24, branch 16:         31 particles.
# Mode  450 of 3168, Q-point  24, branch 17:         31 particles.
# Mode  451 of 3168, Q-point  25, branch  0:         32 particles.
# Mode  452 of 3168, Q-point  25, branch  1:         32 particles.
# Mode  453 of 3168, Q-point  25, branch  2:         32 particles.
# Mode  454 of 3168, Q-point  25, branch  3:         32 particles.
# Mode  455 of 3168, Q-point  25, branch  4:         32 particles.
# Mode  456 of 3168, Q-point  25, branch  5:         32 particles.
# Mode  457 of 3168, Q-point  25, branch  6:         32 particles.
# Mode  458 of 3168, Q-point  25, branch  7:         32 particles.
# Mode  459 of 3168, Q-point  25, branch  8:         32 particles.
# Mode  460 of 3168, Q-point  25, branch  9:         32 particles.
# Mode  461 of 3168, Q-point  25, branch 10:         31 particles.
# Mode  462 of 3168, Q-point  25, branch 11:         31 particles.
# Mode  463 of 3168, Q-point  25, branch 12:         31 particles.
# Mode  464 of 3168, Q-point  25, branch 13:         31 particles.
# Mode  465 of 3168, Q-point  25, branch 14:         31 particles.
# Mode  466 of 3168, Q-point  25, branch 15:         31 particles.
# Mode  467 of 3168, Q-point  25, branch 16:         31 particles.
# Mode  468 of 3168, Q-point  25, branch 17:         31 particles.
# Mode  469 of 3168, Q-point  26, branch  0:         32 particles.
# Mode  470 of 3168, Q-point  26, branch  1:         32 particles.
# Mode  471 of 3168, Q-point  26, branch  2:         32 particles.
# Mode  472 of 3168, Q-point  26, branch  3:         32 particles.
# Mode  473 of 3168, Q-point  26, branch  4:         32 particles.
# Mode  474 of 3168, Q-point  26, branch  5:         32 particles.
# Mode  475 of 3168, Q-point  26, branch  6:         32 particles.
# Mode  476 of 3168, Q-point  26, branch  7:         32 particles.
# Mode  477 of 3168, Q-point  26, branch  8:         32 particles.
# Mode  478 of 3168, Q-point  26, branch  9:         32 particles.
# Mode  479 of 3168, Q-point  26, branch 10:         31 particles.
# Mode  480 of 3168, Q-point  26, branch 11:         31 particles.
# Mode  481 of 3168, Q-point  26, branch 12:         31 particles.
# Mode  482 of 3168, Q-point  26, branch 13:         31 particles.
# Mode  483 of 3168, Q-point  26, branch 14:         31 particles.
# Mode  484 of 3168, Q-point  26, branch 15:         31 particles.
# Mode  485 of 3168, Q-point  26, branch 16:         31 particles.
# Mode  486 of 3168, Q-point  26, branch 17:         31 particles.
# Mode  487 of 3168, Q-point  27, branch  0:         32 particles.
# Mode  488 of 3168, Q-point  27, branch  1:         32 particles.
# Mode  489 of 3168, Q-point  27, branch  2:         32 particles.
# Mode  490 of 3168, Q-point  27, branch  3:         32 particles.
# Mode  491 of 3168, Q-point  27, branch  4:         32 particles.
# Mode  492 of 3168, Q-point  27, branch  5:         32 particles.
# Mode  493 of 3168, Q-point  27, branch  6:         32 particles.
# Mode  494 of 3168, Q-point  27, branch  7:         32 particles.
# Mode  495 of 3168, Q-point  27, branch  8:         32 particles.
# Mode  496 of 3168, Q-point  27, branch  9:         32 particles.
# Mode  497 of 3168, Q-point  27, branch 10:         31 particles.
# Mode  498 of 3168, Q-point  27, branch 11:         31 particles.
# Mode  499 of 3168, Q-point  27, branch 12:         31 particles.
# Mode  500 of 3168, Q-point  27, branch 13:         31 particles.
# Mode  501 of 3168, Q-point  27, branch 14:         31 particles.
# Mode  502 of 3168, Q-point  27, branch 15:         31 particles.
# Mode  503 of 3168, Q-point  27, branch 16:         31 particles.
# Mode  504 of 3168, Q-point  27, branch 17:         31 particles.
# Mode  505 of 3168, Q-point  28, branch  0:         32 particles.
# Mode  506 of 3168, Q-point  28, branch  1:         32 particles.
# Mode  507 of 3168, Q-point  28, branch  2:         32 particles.
# Mode  508 of 3168, Q-point  28, branch  3:         32 particles.
# Mode  509 of 3168, Q-point  28, branch  4:         32 particles.
# Mode  510 of 3168, Q-point  28, branch  5:         32 particles.
# Mode  511 of 3168, Q-point  28, branch  6:         32 particles.
# Mode  512 of 3168, Q-point  28, branch  7:         32 particles.
# Mode  513 of 3168, Q-point  28, branch  8:         32 particles.
# Mode  514 of 3168, Q-point  28, branch  9:         32 particles.
# Mode  515 of 3168, Q-point  28, branch 10:         31 particles.
# Mode  516 of 3168, Q-point  28, branch 11:         31 particles.
# Mode  517 of 3168, Q-point  28, branch 12:         31 particles.
# Mode  518 of 3168, Q-point  28, branch 13:         31 particles.
# Mode  519 of 3168, Q-point  28, branch 14:         31 particles.
# Mode  520 of 3168, Q-point  28, branch 15:         31 particles.
# Mode  521 of 3168, Q-point  28, branch 16:         31 particles.
# Mode  522 of 3168, Q-point  28, branch 17:         31 particles.
# Mode  523 of 3168, Q-point  29, branch  0:         32 particles.
# Mode  524 of 3168, Q-point  29, branch  1:         32 particles.
# Mode  525 of 3168, Q-point  29, branch  2:         32 particles.
# Mode  526 of 3168, Q-point  29, branch  3:         32 particles.
# Mode  527 of 3168, Q-point  29, branch  4:         32 particles.
# Mode  528 of 3168, Q-point  29, branch  5:         32 particles.
# Mode  529 of 3168, Q-point  29, branch  6:         32 particles.
# Mode  530 of 3168, Q-point  29, branch  7:         32 particles.
# Mode  531 of 3168, Q-point  29, branch  8:         32 particles.
# Mode  532 of 3168, Q-point  29, branch  9:         32 particles.
# Mode  533 of 3168, Q-point  29, branch 10:         31 particles.
# Mode  534 of 3168, Q-point  29, branch 11:         31 particles.
# Mode  535 of 3168, Q-point  29, branch 12:         31 particles.
# Mode  536 of 3168, Q-point  29, branch 13:         31 particles.
# Mode  537 of 3168, Q-point  29, branch 14:         31 particles.
# Mode  538 of 3168, Q-point  29, branch 15:         31 particles.
# Mode  539 of 3168, Q-point  29, branch 16:         31 particles.
# Mode  540 of 3168, Q-point  29, branch 17:         31 particles.
# Mode  541 of 3168, Q-point  30, branch  0:         32 particles.
# Mode  542 of 3168, Q-point  30, branch  1:         32 particles.
# Mode  543 of 3168, Q-point  30, branch  2:         32 particles.
# Mode  544 of 3168, Q-point  30, branch  3:         32 particles.
# Mode  545 of 3168, Q-point  30, branch  4:         32 particles.
# Mode  546 of 3168, Q-point  30, branch  5:         32 particles.
# Mode  547 of 3168, Q-point  30, branch  6:         32 particles.
# Mode  548 of 3168, Q-point  30, branch  7:         32 particles.
# Mode  549 of 3168, Q-point  30, branch  8:         32 particles.
# Mode  550 of 3168, Q-point  30, branch  9:         32 particles.
# Mode  551 of 3168, Q-point  30, branch 10:         31 particles.
# Mode  552 of 3168, Q-point  30, branch 11:         31 particles.
# Mode  553 of 3168, Q-point  30, branch 12:         31 particles.
# Mode  554 of 3168, Q-point  30, branch 13:         31 particles.
# Mode  555 of 3168, Q-point  30, branch 14:         31 particles.
# Mode  556 of 3168, Q-point  30, branch 15:         31 particles.
# Mode  557 of 3168, Q-point  30, branch 16:         31 particles.
# Mode  558 of 3168, Q-point  30, branch 17:         31 particles.
# Mode  559 of 3168, Q-point  31, branch  0:         32 particles.
# Mode  560 of 3168, Q-point  31, branch  1:         32 particles.
# Mode  561 of 3168, Q-point  31, branch  2:         32 particles.
# Mode  562 of 3168, Q-point  31, branch  3:         32 particles.
# Mode  563 of 3168, Q-point  31, branch  4:         32 particles.
# Mode  564 of 3168, Q-point  31, branch  5:         32 particles.
# Mode  565 of 3168, Q-point  31, branch  6:         32 particles.
# Mode  566 of 3168, Q-point  31, branch  7:         32 particles.
# Mode  567 of 3168, Q-point  31, branch  8:         32 particles.
# Mode  568 of 3168, Q-point  31, branch  9:         32 particles.
# Mode  569 of 3168, Q-point  31, branch 10:         31 particles.
# Mode  570 of 3168, Q-point  31, branch 11:         31 particles.
# Mode  571 of 3168, Q-point  31, branch 12:         31 particles.
# Mode  572 of 3168, Q-point  31, branch 13:         31 particles.
# Mode  573 of 3168, Q-point  31, branch 14:         31 particles.
# Mode  574 of 3168, Q-point  31, branch 15:         31 particles.
# Mode  575 of 3168, Q-point  31, branch 16:         31 particles.
# Mode  576 of 3168, Q-point  31, branch 17:         31 particles.
# Mode  577 of 3168, Q-point  32, branch  0:         32 particles.
# Mode  578 of 3168, Q-point  32, branch  1:         32 particles.
# Mode  579 of 3168, Q-point  32, branch  2:         32 particles.
# Mode  580 of 3168, Q-point  32, branch  3:         32 particles.
# Mode  581 of 3168, Q-point  32, branch  4:         32 particles.
# Mode  582 of 3168, Q-point  32, branch  5:         32 particles.
# Mode  583 of 3168, Q-point  32, branch  6:         32 particles.
# Mode  584 of 3168, Q-point  32, branch  7:         32 particles.
# Mode  585 of 3168, Q-point  32, branch  8:         32 particles.
# Mode  586 of 3168, Q-point  32, branch  9:         32 particles.
# Mode  587 of 3168, Q-point  32, branch 10:         31 particles.
# Mode  588 of 3168, Q-point  32, branch 11:         31 particles.
# Mode  589 of 3168, Q-point  32, branch 12:         31 particles.
# Mode  590 of 3168, Q-point  32, branch 13:         31 particles.
# Mode  591 of 3168, Q-point  32, branch 14:         31 particles.
# Mode  592 of 3168, Q-point  32, branch 15:         31 particles.
# Mode  593 of 3168, Q-point  32, branch 16:         31 particles.
# Mode  594 of 3168, Q-point  32, branch 17:         31 particles.
# Mode  595 of 3168, Q-point  33, branch  0:         32 particles.
# Mode  596 of 3168, Q-point  33, branch  1:         32 particles.
# Mode  597 of 3168, Q-point  33, branch  2:         32 particles.
# Mode  598 of 3168, Q-point  33, branch  3:         32 particles.
# Mode  599 of 3168, Q-point  33, branch  4:         32 particles.
# Mode  600 of 3168, Q-point  33, branch  5:         32 particles.
# Mode  601 of 3168, Q-point  33, branch  6:         32 particles.
# Mode  602 of 3168, Q-point  33, branch  7:         32 particles.
# Mode  603 of 3168, Q-point  33, branch  8:         32 particles.
# Mode  604 of 3168, Q-point  33, branch  9:         32 particles.
# Mode  605 of 3168, Q-point  33, branch 10:         31 particles.
# Mode  606 of 3168, Q-point  33, branch 11:         31 particles.
# Mode  607 of 3168, Q-point  33, branch 12:         31 particles.
# Mode  608 of 3168, Q-point  33, branch 13:         31 particles.
# Mode  609 of 3168, Q-point  33, branch 14:         31 particles.
# Mode  610 of 3168, Q-point  33, branch 15:         31 particles.
# Mode  611 of 3168, Q-point  33, branch 16:         31 particles.
# Mode  612 of 3168, Q-point  33, branch 17:         31 particles.
# Mode  613 of 3168, Q-point  34, branch  0:         32 particles.
# Mode  614 of 3168, Q-point  34, branch  1:         32 particles.
# Mode  615 of 3168, Q-point  34, branch  2:         32 particles.
# Mode  616 of 3168, Q-point  34, branch  3:         32 particles.
# Mode  617 of 3168, Q-point  34, branch  4:         32 particles.
# Mode  618 of 3168, Q-point  34, branch  5:         32 particles.
# Mode  619 of 3168, Q-point  34, branch  6:         32 particles.
# Mode  620 of 3168, Q-point  34, branch  7:         32 particles.
# Mode  621 of 3168, Q-point  34, branch  8:         32 particles.
# Mode  622 of 3168, Q-point  34, branch  9:         32 particles.
# Mode  623 of 3168, Q-point  34, branch 10:         31 particles.
# Mode  624 of 3168, Q-point  34, branch 11:         31 particles.
# Mode  625 of 3168, Q-point  34, branch 12:         31 particles.
# Mode  626 of 3168, Q-point  34, branch 13:         31 particles.
# Mode  627 of 3168, Q-point  34, branch 14:         31 particles.
# Mode  628 of 3168, Q-point  34, branch 15:         31 particles.
# Mode  629 of 3168, Q-point  34, branch 16:         31 particles.
# Mode  630 of 3168, Q-point  34, branch 17:         31 particles.
# Mode  631 of 3168, Q-point  35, branch  0:         32 particles.
# Mode  632 of 3168, Q-point  35, branch  1:         32 particles.
# Mode  633 of 3168, Q-point  35, branch  2:         32 particles.
# Mode  634 of 3168, Q-point  35, branch  3:         32 particles.
# Mode  635 of 3168, Q-point  35, branch  4:         32 particles.
# Mode  636 of 3168, Q-point  35, branch  5:         32 particles.
# Mode  637 of 3168, Q-point  35, branch  6:         32 particles.
# Mode  638 of 3168, Q-point  35, branch  7:         32 particles.
# Mode  639 of 3168, Q-point  35, branch  8:         32 particles.
# Mode  640 of 3168, Q-point  35, branch  9:         32 particles.
# Mode  641 of 3168, Q-point  35, branch 10:         31 particles.
# Mode  642 of 3168, Q-point  35, branch 11:         31 particles.
# Mode  643 of 3168, Q-point  35, branch 12:         31 particles.
# Mode  644 of 3168, Q-point  35, branch 13:         31 particles.
# Mode  645 of 3168, Q-point  35, branch 14:         31 particles.
# Mode  646 of 3168, Q-point  35, branch 15:         31 particles.
# Mode  647 of 3168, Q-point  35, branch 16:         31 particles.
# Mode  648 of 3168, Q-point  35, branch 17:         31 particles.
# Mode  649 of 3168, Q-point  36, branch  0:         32 particles.
# Mode  650 of 3168, Q-point  36, branch  1:         32 particles.
# Mode  651 of 3168, Q-point  36, branch  2:         32 particles.
# Mode  652 of 3168, Q-point  36, branch  3:         32 particles.
# Mode  653 of 3168, Q-point  36, branch  4:         32 particles.
# Mode  654 of 3168, Q-point  36, branch  5:         32 particles.
# Mode  655 of 3168, Q-point  36, branch  6:         32 particles.
# Mode  656 of 3168, Q-point  36, branch  7:         32 particles.
# Mode  657 of 3168, Q-point  36, branch  8:         32 particles.
# Mode  658 of 3168, Q-point  36, branch  9:         32 particles.
# Mode  659 of 3168, Q-point  36, branch 10:         31 particles.
# Mode  660 of 3168, Q-point  36, branch 11:         31 particles.
# Mode  661 of 3168, Q-point  36, branch 12:         31 particles.
# Mode  662 of 3168, Q-point  36, branch 13:         31 particles.
# Mode  663 of 3168, Q-point  36, branch 14:         31 particles.
# Mode  664 of 3168, Q-point  36, branch 15:         31 particles.
# Mode  665 of 3168, Q-point  36, branch 16:         31 particles.
# Mode  666 of 3168, Q-point  36, branch 17:         31 particles.
# Mode  667 of 3168, Q-point  37, branch  0:         32 particles.
# Mode  668 of 3168, Q-point  37, branch  1:         32 particles.
# Mode  669 of 3168, Q-point  37, branch  2:         32 particles.
# Mode  670 of 3168, Q-point  37, branch  3:         32 particles.
# Mode  671 of 3168, Q-point  37, branch  4:         32 particles.
# Mode  672 of 3168, Q-point  37, branch  5:         32 particles.
# Mode  673 of 3168, Q-point  37, branch  6:         32 particles.
# Mode  674 of 3168, Q-point  37, branch  7:         32 particles.
# Mode  675 of 3168, Q-point  37, branch  8:         32 particles.
# Mode  676 of 3168, Q-point  37, branch  9:         32 particles.
# Mode  677 of 3168, Q-point  37, branch 10:         31 particles.
# Mode  678 of 3168, Q-point  37, branch 11:         31 particles.
# Mode  679 of 3168, Q-point  37, branch 12:         31 particles.
# Mode  680 of 3168, Q-point  37, branch 13:         31 particles.
# Mode  681 of 3168, Q-point  37, branch 14:         31 particles.
# Mode  682 of 3168, Q-point  37, branch 15:         31 particles.
# Mode  683 of 3168, Q-point  37, branch 16:         31 particles.
# Mode  684 of 3168, Q-point  37, branch 17:         31 particles.
# Mode  685 of 3168, Q-point  38, branch  0:         32 particles.
# Mode  686 of 3168, Q-point  38, branch  1:         32 particles.
# Mode  687 of 3168, Q-point  38, branch  2:         32 particles.
# Mode  688 of 3168, Q-point  38, branch  3:         32 particles.
# Mode  689 of 3168, Q-point  38, branch  4:         32 particles.
# Mode  690 of 3168, Q-point  38, branch  5:         32 particles.
# Mode  691 of 3168, Q-point  38, branch  6:         32 particles.
# Mode  692 of 3168, Q-point  38, branch  7:         32 particles.
# Mode  693 of 3168, Q-point  38, branch  8:         32 particles.
# Mode  694 of 3168, Q-point  38, branch  9:         32 particles.
# Mode  695 of 3168, Q-point  38, branch 10:         31 particles.
# Mode  696 of 3168, Q-point  38, branch 11:         31 particles.
# Mode  697 of 3168, Q-point  38, branch 12:         31 particles.
# Mode  698 of 3168, Q-point  38, branch 13:         31 particles.
# Mode  699 of 3168, Q-point  38, branch 14:         31 particles.
# Mode  700 of 3168, Q-point  38, branch 15:         31 particles.
# Mode  701 of 3168, Q-point  38, branch 16:         31 particles.
# Mode  702 of 3168, Q-point  38, branch 17:         31 particles.
# Mode  703 of 3168, Q-point  39, branch  0:         32 particles.
# Mode  704 of 3168, Q-point  39, branch  1:         32 particles.
# Mode  705 of 3168, Q-point  39, branch  2:         32 particles.
# Mode  706 of 3168, Q-point  39, branch  3:         32 particles.
# Mode  707 of 3168, Q-point  39, branch  4:         32 particles.
# Mode  708 of 3168, Q-point  39, branch  5:         32 particles.
# Mode  709 of 3168, Q-point  39, branch  6:         32 particles.
# Mode  710 of 3168, Q-point  39, branch  7:         32 particles.
# Mode  711 of 3168, Q-point  39, branch  8:         32 particles.
# Mode  712 of 3168, Q-point  39, branch  9:         32 particles.
# Mode  713 of 3168, Q-point  39, branch 10:         31 particles.
# Mode  714 of 3168, Q-point  39, branch 11:         31 particles.
# Mode  715 of 3168, Q-point  39, branch 12:         31 particles.
# Mode  716 of 3168, Q-point  39, branch 13:         31 particles.
# Mode  717 of 3168, Q-point  39, branch 14:         31 particles.
# Mode  718 of 3168, Q-point  39, branch 15:         31 particles.
# Mode  719 of 3168, Q-point  39, branch 16:         31 particles.
# Mode  720 of 3168, Q-point  39, branch 17:         31 particles.
# Mode  721 of 3168, Q-point  40, branch  0:         32 particles.
# Mode  722 of 3168, Q-point  40, branch  1:         32 particles.
# Mode  723 of 3168, Q-point  40, branch  2:         32 particles.
# Mode  724 of 3168, Q-point  40, branch  3:         32 particles.
# Mode  725 of 3168, Q-point  40, branch  4:         32 particles.
# Mode  726 of 3168, Q-point  40, branch  5:         32 particles.
# Mode  727 of 3168, Q-point  40, branch  6:         32 particles.
# Mode  728 of 3168, Q-point  40, branch  7:         32 particles.
# Mode  729 of 3168, Q-point  40, branch  8:         32 particles.
# Mode  730 of 3168, Q-point  40, branch  9:         32 particles.
# Mode  731 of 3168, Q-point  40, branch 10:         31 particles.
# Mode  732 of 3168, Q-point  40, branch 11:         31 particles.
# Mode  733 of 3168, Q-point  40, branch 12:         31 particles.
# Mode  734 of 3168, Q-point  40, branch 13:         31 particles.
# Mode  735 of 3168, Q-point  40, branch 14:         31 particles.
# Mode  736 of 3168, Q-point  40, branch 15:         31 particles.
# Mode  737 of 3168, Q-point  40, branch 16:         31 particles.
# Mode  738 of 3168, Q-point  40, branch 17:         31 particles.
# ...
# Mode 2924 of 3168, Q-point 162, branch  7:         32 particles.
# Mode 2925 of 3168, Q-point 162, branch  8:         32 particles.
# Mode 2926 of 3168, Q-point 162, branch  9:         32 particles.
# Mode 2927 of 3168, Q-point 162, branch 10:         31 particles.
# Mode 2928 of 3168, Q-point 162, branch 11:         31 particles.
# Mode 2929 of 3168, Q-point 162, branch 12:         31 particles.
# Mode 2930 of 3168, Q-point 162, branch 13:         31 particles.
# Mode 2931 of 3168, Q-point 162, branch 14:         31 particles.
# Mode 2932 of 3168, Q-point 162, branch 15:         31 particles.
# Mode 2933 of 3168, Q-point 162, branch 16:         31 particles.
# Mode 2934 of 3168, Q-point 162, branch 17:         31 particles.
# Mode 2935 of 3168, Q-point 163, branch  0:         32 particles.
# Mode 2936 of 3168, Q-point 163, branch  1:         32 particles.
# Mode 2937 of 3168, Q-point 163, branch  2:         32 particles.
# Mode 2938 of 3168, Q-point 163, branch  3:         32 particles.
# Mode 2939 of 3168, Q-point 163, branch  4:         32 particles.
# Mode 2940 of 3168, Q-point 163, branch  5:         32 particles.
# Mode 2941 of 3168, Q-point 163, branch  6:         32 particles.
# Mode 2942 of 3168, Q-point 163, branch  7:         32 particles.
# Mode 2943 of 3168, Q-point 163, branch  8:         32 particles.
# Mode 2944 of 3168, Q-point 163, branch  9:         32 particles.
# Mode 2945 of 3168, Q-point 163, branch 10:         31 particles.
# Mode 2946 of 3168, Q-point 163, branch 11:         31 particles.
# Mode 2947 of 3168, Q-point 163, branch 12:         31 particles.
# Mode 2948 of 3168, Q-point 163, branch 13:         31 particles.
# Mode 2949 of 3168, Q-point 163, branch 14:         31 particles.
# Mode 2950 of 3168, Q-point 163, branch 15:         31 particles.
# Mode 2951 of 3168, Q-point 163, branch 16:         31 particles.
# Mode 2952 of 3168, Q-point 163, branch 17:         31 particles.
# Mode 2953 of 3168, Q-point 164, branch  0:         32 particles.
# Mode 2954 of 3168, Q-point 164, branch  1:         32 particles.
# Mode 2955 of 3168, Q-point 164, branch  2:         32 particles.
# Mode 2956 of 3168, Q-point 164, branch  3:         32 particles.
# Mode 2957 of 3168, Q-point 164, branch  4:         32 particles.
# Mode 2958 of 3168, Q-point 164, branch  5:         32 particles.
# Mode 2959 of 3168, Q-point 164, branch  6:         32 particles.
# Mode 2960 of 3168, Q-point 164, branch  7:         32 particles.
# Mode 2961 of 3168, Q-point 164, branch  8:         32 particles.
# Mode 2962 of 3168, Q-point 164, branch  9:         32 particles.
# Mode 2963 of 3168, Q-point 164, branch 10:         31 particles.
# Mode 2964 of 3168, Q-point 164, branch 11:         31 particles.
# Mode 2965 of 3168, Q-point 164, branch 12:         31 particles.
# Mode 2966 of 3168, Q-point 164, branch 13:         31 particles.
# Mode 2967 of 3168, Q-point 164, branch 14:         31 particles.
# Mode 2968 of 3168, Q-point 164, branch 15:         31 particles.
# Mode 2969 of 3168, Q-point 164, branch 16:         31 particles.
# Mode 2970 of 3168, Q-point 164, branch 17:         31 particles.
# Mode 2971 of 3168, Q-point 165, branch  0:         32 particles.
# Mode 2972 of 3168, Q-point 165, branch  1:         32 particles.
# Mode 2973 of 3168, Q-point 165, branch  2:         32 particles.
# Mode 2974 of 3168, Q-point 165, branch  3:         32 particles.
# Mode 2975 of 3168, Q-point 165, branch  4:         32 particles.
# Mode 2976 of 3168, Q-point 165, branch  5:         32 particles.
# Mode 2977 of 3168, Q-point 165, branch  6:         32 particles.
# Mode 2978 of 3168, Q-point 165, branch  7:         32 particles.
# Mode 2979 of 3168, Q-point 165, branch  8:         32 particles.
# Mode 2980 of 3168, Q-point 165, branch  9:         32 particles.
# Mode 2981 of 3168, Q-point 165, branch 10:         31 particles.
# Mode 2982 of 3168, Q-point 165, branch 11:         31 particles.
# Mode 2983 of 3168, Q-point 165, branch 12:         31 particles.
# Mode 2984 of 3168, Q-point 165, branch 13:         31 particles.
# Mode 2985 of 3168, Q-point 165, branch 14:         31 particles.
# Mode 2986 of 3168, Q-point 165, branch 15:         31 particles.
# Mode 2987 of 3168, Q-point 165, branch 16:         31 particles.
# Mode 2988 of 3168, Q-point 165, branch 17:         31 particles.
# Mode 2989 of 3168, Q-point 166, branch  0:         32 particles.
# Mode 2990 of 3168, Q-point 166, branch  1:         32 particles.
# Mode 2991 of 3168, Q-point 166, branch  2:         32 particles.
# Mode 2992 of 3168, Q-point 166, branch  3:         32 particles.
# Mode 2993 of 3168, Q-point 166, branch  4:         32 particles.
# Mode 2994 of 3168, Q-point 166, branch  5:         32 particles.
# Mode 2995 of 3168, Q-point 166, branch  6:         32 particles.
# Mode 2996 of 3168, Q-point 166, branch  7:         32 particles.
# Mode 2997 of 3168, Q-point 166, branch  8:         32 particles.
# Mode 2998 of 3168, Q-point 166, branch  9:         32 particles.
# Mode 2999 of 3168, Q-point 166, branch 10:         31 particles.
# Mode 3000 of 3168, Q-point 166, branch 11:         31 particles.
# Mode 3001 of 3168, Q-point 166, branch 12:         31 particles.
# Mode 3002 of 3168, Q-point 166, branch 13:         31 particles.
# Mode 3003 of 3168, Q-point 166, branch 14:         31 particles.
# Mode 3004 of 3168, Q-point 166, branch 15:         31 particles.
# Mode 3005 of 3168, Q-point 166, branch 16:         31 particles.
# Mode 3006 of 3168, Q-point 166, branch 17:         31 particles.
# Mode 3007 of 3168, Q-point 167, branch  0:         32 particles.
# Mode 3008 of 3168, Q-point 167, branch  1:         32 particles.
# Mode 3009 of 3168, Q-point 167, branch  2:         32 particles.
# Mode 3010 of 3168, Q-point 167, branch  3:         32 particles.
# Mode 3011 of 3168, Q-point 167, branch  4:         32 particles.
# Mode 3012 of 3168, Q-point 167, branch  5:         32 particles.
# Mode 3013 of 3168, Q-point 167, branch  6:         32 particles.
# Mode 3014 of 3168, Q-point 167, branch  7:         32 particles.
# Mode 3015 of 3168, Q-point 167, branch  8:         32 particles.
# Mode 3016 of 3168, Q-point 167, branch  9:         32 particles.
# Mode 3017 of 3168, Q-point 167, branch 10:         31 particles.
# Mode 3018 of 3168, Q-point 167, branch 11:         31 particles.
# Mode 3019 of 3168, Q-point 167, branch 12:         31 particles.
# Mode 3020 of 3168, Q-point 167, branch 13:         31 particles.
# Mode 3021 of 3168, Q-point 167, branch 14:         31 particles.
# Mode 3022 of 3168, Q-point 167, branch 15:         31 particles.
# Mode 3023 of 3168, Q-point 167, branch 16:         31 particles.
# Mode 3024 of 3168, Q-point 167, branch 17:         31 particles.
# Mode 3025 of 3168, Q-point 168, branch  0:         32 particles.
# Mode 3026 of 3168, Q-point 168, branch  1:         32 particles.
# Mode 3027 of 3168, Q-point 168, branch  2:         32 particles.
# Mode 3028 of 3168, Q-point 168, branch  3:         32 particles.
# Mode 3029 of 3168, Q-point 168, branch  4:         32 particles.
# Mode 3030 of 3168, Q-point 168, branch  5:         32 particles.
# Mode 3031 of 3168, Q-point 168, branch  6:         32 particles.
# Mode 3032 of 3168, Q-point 168, branch  7:         32 particles.
# Mode 3033 of 3168, Q-point 168, branch  8:         32 particles.
# Mode 3034 of 3168, Q-point 168, branch  9:         32 particles.
# Mode 3035 of 3168, Q-point 168, branch 10:         31 particles.
# Mode 3036 of 3168, Q-point 168, branch 11:         31 particles.
# Mode 3037 of 3168, Q-point 168, branch 12:         31 particles.
# Mode 3038 of 3168, Q-point 168, branch 13:         31 particles.
# Mode 3039 of 3168, Q-point 168, branch 14:         31 particles.
# Mode 3040 of 3168, Q-point 168, branch 15:         31 particles.
# Mode 3041 of 3168, Q-point 168, branch 16:         31 particles.
# Mode 3042 of 3168, Q-point 168, branch 17:         31 particles.
# Mode 3043 of 3168, Q-point 169, branch  0:         32 particles.
# Mode 3044 of 3168, Q-point 169, branch  1:         32 particles.
# Mode 3045 of 3168, Q-point 169, branch  2:         32 particles.
# Mode 3046 of 3168, Q-point 169, branch  3:         32 particles.
# Mode 3047 of 3168, Q-point 169, branch  4:         32 particles.
# Mode 3048 of 3168, Q-point 169, branch  5:         32 particles.
# Mode 3049 of 3168, Q-point 169, branch  6:         32 particles.
# Mode 3050 of 3168, Q-point 169, branch  7:         32 particles.
# Mode 3051 of 3168, Q-point 169, branch  8:         32 particles.
# Mode 3052 of 3168, Q-point 169, branch  9:         32 particles.
# Mode 3053 of 3168, Q-point 169, branch 10:         31 particles.
# Mode 3054 of 3168, Q-point 169, branch 11:         31 particles.
# Mode 3055 of 3168, Q-point 169, branch 12:         31 particles.
# Mode 3056 of 3168, Q-point 169, branch 13:         31 particles.
# Mode 3057 of 3168, Q-point 169, branch 14:         31 particles.
# Mode 3058 of 3168, Q-point 169, branch 15:         31 particles.
# Mode 3059 of 3168, Q-point 169, branch 16:         31 particles.
# Mode 3060 of 3168, Q-point 169, branch 17:         31 particles.
# Mode 3061 of 3168, Q-point 170, branch  0:         32 particles.
# Mode 3062 of 3168, Q-point 170, branch  1:         32 particles.
# Mode 3063 of 3168, Q-point 170, branch  2:         32 particles.
# Mode 3064 of 3168, Q-point 170, branch  3:         32 particles.
# Mode 3065 of 3168, Q-point 170, branch  4:         32 particles.
# Mode 3066 of 3168, Q-point 170, branch  5:         32 particles.
# Mode 3067 of 3168, Q-point 170, branch  6:         32 particles.
# Mode 3068 of 3168, Q-point 170, branch  7:         32 particles.
# Mode 3069 of 3168, Q-point 170, branch  8:         32 particles.
# Mode 3070 of 3168, Q-point 170, branch  9:         32 particles.
# Mode 3071 of 3168, Q-point 170, branch 10:         31 particles.
# Mode 3072 of 3168, Q-point 170, branch 11:         31 particles.
# Mode 3073 of 3168, Q-point 170, branch 12:         31 particles.
# Mode 3074 of 3168, Q-point 170, branch 13:         31 particles.
# Mode 3075 of 3168, Q-point 170, branch 14:         31 particles.
# Mode 3076 of 3168, Q-point 170, branch 15:         31 particles.
# Mode 3077 of 3168, Q-point 170, branch 16:         31 particles.
# Mode 3078 of 3168, Q-point 170, branch 17:         31 particles.
# Mode 3079 of 3168, Q-point 171, branch  0:         32 particles.
# Mode 3080 of 3168, Q-point 171, branch  1:         32 particles.
# Mode 3081 of 3168, Q-point 171, branch  2:         32 particles.
# Mode 3082 of 3168, Q-point 171, branch  3:         32 particles.
# Mode 3083 of 3168, Q-point 171, branch  4:         32 particles.
# Mode 3084 of 3168, Q-point 171, branch  5:         32 particles.
# Mode 3085 of 3168, Q-point 171, branch  6:         32 particles.
# Mode 3086 of 3168, Q-point 171, branch  7:         32 particles.
# Mode 3087 of 3168, Q-point 171, branch  8:         32 particles.
# Mode 3088 of 3168, Q-point 171, branch  9:         32 particles.
# Mode 3089 of 3168, Q-point 171, branch 10:         31 particles.
# Mode 3090 of 3168, Q-point 171, branch 11:         31 particles.
# Mode 3091 of 3168, Q-point 171, branch 12:         31 particles.
# Mode 3092 of 3168, Q-point 171, branch 13:         31 particles.
# Mode 3093 of 3168, Q-point 171, branch 14:         31 particles.
# Mode 3094 of 3168, Q-point 171, branch 15:         31 particles.
# Mode 3095 of 3168, Q-point 171, branch 16:         31 particles.
# Mode 3096 of 3168, Q-point 171, branch 17:         31 particles.
# Mode 3097 of 3168, Q-point 172, branch  0:         32 particles.
# Mode 3098 of 3168, Q-point 172, branch  1:         32 particles.
# Mode 3099 of 3168, Q-point 172, branch  2:         32 particles.
# Mode 3100 of 3168, Q-point 172, branch  3:         32 particles.
# Mode 3101 of 3168, Q-point 172, branch  4:         32 particles.
# Mode 3102 of 3168, Q-point 172, branch  5:         32 particles.
# Mode 3103 of 3168, Q-point 172, branch  6:         32 particles.
# Mode 3104 of 3168, Q-point 172, branch  7:         32 particles.
# Mode 3105 of 3168, Q-point 172, branch  8:         32 particles.
# Mode 3106 of 3168, Q-point 172, branch  9:         32 particles.
# Mode 3107 of 3168, Q-point 172, branch 10:         31 particles.
# Mode 3108 of 3168, Q-point 172, branch 11:         31 particles.
# Mode 3109 of 3168, Q-point 172, branch 12:         31 particles.
# Mode 3110 of 3168, Q-point 172, branch 13:         31 particles.
# Mode 3111 of 3168, Q-point 172, branch 14:         31 particles.
# Mode 3112 of 3168, Q-point 172, branch 15:         31 particles.
# Mode 3113 of 3168, Q-point 172, branch 16:         31 particles.
# Mode 3114 of 3168, Q-point 172, branch 17:         31 particles.
# Mode 3115 of 3168, Q-point 173, branch  0:         32 particles.
# Mode 3116 of 3168, Q-point 173, branch  1:         32 particles.
# Mode 3117 of 3168, Q-point 173, branch  2:         32 particles.
# Mode 3118 of 3168, Q-point 173, branch  3:         32 particles.
# Mode 3119 of 3168, Q-point 173, branch  4:         32 particles.
# Mode 3120 of 3168, Q-point 173, branch  5:         32 particles.
# Mode 3121 of 3168, Q-point 173, branch  6:         32 particles.
# Mode 3122 of 3168, Q-point 173, branch  7:         32 particles.
# Mode 3123 of 3168, Q-point 173, branch  8:         32 particles.
# Mode 3124 of 3168, Q-point 173, branch  9:         32 particles.
# Mode 3125 of 3168, Q-point 173, branch 10:         31 particles.
# Mode 3126 of 3168, Q-point 173, branch 11:         31 particles.
# Mode 3127 of 3168, Q-point 173, branch 12:         31 particles.
# Mode 3128 of 3168, Q-point 173, branch 13:         31 particles.
# Mode 3129 of 3168, Q-point 173, branch 14:         31 particles.
# Mode 3130 of 3168, Q-point 173, branch 15:         31 particles.
# Mode 3131 of 3168, Q-point 173, branch 16:         31 particles.
# Mode 3132 of 3168, Q-point 173, branch 17:         31 particles.
# Mode 3133 of 3168, Q-point 174, branch  0:         32 particles.
# Mode 3134 of 3168, Q-point 174, branch  1:         32 particles.
# Mode 3135 of 3168, Q-point 174, branch  2:         32 particles.
# Mode 3136 of 3168, Q-point 174, branch  3:         32 particles.
# Mode 3137 of 3168, Q-point 174, branch  4:         32 particles.
# Mode 3138 of 3168, Q-point 174, branch  5:         32 particles.
# Mode 3139 of 3168, Q-point 174, branch  6:         32 particles.
# Mode 3140 of 3168, Q-point 174, branch  7:         32 particles.
# Mode 3141 of 3168, Q-point 174, branch  8:         32 particles.
# Mode 3142 of 3168, Q-point 174, branch  9:         32 particles.
# Mode 3143 of 3168, Q-point 174, branch 10:         31 particles.
# Mode 3144 of 3168, Q-point 174, branch 11:         31 particles.
# Mode 3145 of 3168, Q-point 174, branch 12:         31 particles.
# Mode 3146 of 3168, Q-point 174, branch 13:         31 particles.
# Mode 3147 of 3168, Q-point 174, branch 14:         31 particles.
# Mode 3148 of 3168, Q-point 174, branch 15:         31 particles.
# Mode 3149 of 3168, Q-point 174, branch 16:         31 particles.
# Mode 3150 of 3168, Q-point 174, branch 17:         31 particles.
# Mode 3151 of 3168, Q-point 175, branch  0:         32 particles.
# Mode 3152 of 3168, Q-point 175, branch  1:         32 particles.
# Mode 3153 of 3168, Q-point 175, branch  2:         32 particles.
# Mode 3154 of 3168, Q-point 175, branch  3:         32 particles.
# Mode 3155 of 3168, Q-point 175, branch  4:         32 particles.
# Mode 3156 of 3168, Q-point 175, branch  5:         32 particles.
# Mode 3157 of 3168, Q-point 175, branch  6:         32 particles.
# Mode 3158 of 3168, Q-point 175, branch  7:         32 particles.
# Mode 3159 of 3168, Q-point 175, branch  8:         32 particles.
# Mode 3160 of 3168, Q-point 175, branch  9:         32 particles.
# Mode 3161 of 3168, Q-point 175, branch 10:         31 particles.
# Mode 3162 of 3168, Q-point 175, branch 11:         31 particles.
# Mode 3163 of 3168, Q-point 175, branch 12:         31 particles.
# Mode 3164 of 3168, Q-point 175, branch 13:         31 particles.
# Mode 3165 of 3168, Q-point 175, branch 14:         31 particles.
# Mode 3166 of 3168, Q-point 175, branch 15:         31 particles.
# Mode 3167 of 3168, Q-point 175, branch 16:         31 particles.
# Mode 3168 of 3168, Q-point 175, branch 17:         31 particles.
# Particles generated! Time: 10.149 s

# %%
# PARTICLE GENERATION (BRUNO'S METHOD)

start = time.time()

modes = np.zeros( (1, 2) )

for i in range(n_of_qpoints):
    for j in range(n_of_branches):

        index = int(i*n_of_branches+j)

        buffer_modes      = np.ones( (ppm_array[index], 2) )
        buffer_modes[:,0] *= i                         
        buffer_modes[:,1] *= j

        modes = np.row_stack( (modes, buffer_modes) )

modes     = np.delete(modes, 0, axis = 0).astype(int)

positions = np.random.rand(n_of_particles, 3)*(limits[1,:] - limits[0,:]) + limits[0,:]
in_points = mesh.contains(positions)

positions = np.delete(positions, ~in_points, axis=0)
new_points = np.random.rand(modes.shape[0]-positions.shape[0], 3)*(limits[1,:] - limits[0,:]) + limits[0,:]

in_points = mesh.contains(new_points)

positions = np.row_stack( (positions, new_points[in_points, :]) )

while np.any(~in_points):
    new_points = np.random.rand(modes.shape[0]-positions.shape[0], 3)*(limits[1,:] - limits[0,:]) + limits[0,:]

    in_points = mesh.contains(new_points)

    positions = np.row_stack( (positions, new_points[in_points, :]) )

    # print('out particles {}'.format(~in_points.sum()))
    

end = time.time()

print('Particles generated! Time: {:.3f} s'.format(end-start))

# fig = plt.figure(figsize = (15, 5))
# for i in range(15):
#     points = positions[ int(i*part_p_mode):int((i+1)*part_p_mode), :]
#     ax = fig.add_subplot(3, 5, i+1, projection='3d')
#     ax.set_box_aspect( (5, 1, 1) )
#     ax.plot(points[:,0], points[:,1], points[:,2], '.')
# plt.tight_layout()
# Out:
# Particles generated! Time: 27.555 s

# %%
# FREQUENCY ASSIGNMENT

# modes = np.zeros( (n_of_particles, 2) )

# modes[:,0] = np.floor(np.random.rand(n_of_particles)*n_of_qpoints)
# modes[:,1] = np.floor(np.random.rand(n_of_particles)*n_of_branches)

# modes = modes.astype(int)

frequencies = np.abs( crystal_omega[modes[:,0], modes[:,1]] )

velocities = np.array(phonons['group_velocity'])[modes[:,0], modes[:,1], :]

# %%
# SLICING

n_of_slices = 10
slice_axis  = 0

slice_size = np.ptp(limits[:,slice_axis])/n_of_slices

T_c = 20
T_h = 50

T_array = np.arange(n_of_slices)*(T_h - T_c)/(n_of_slices-1)+T_c
T_array = np.flip(T_array)

temperatures = np.zeros(frequencies.shape)

particles_per_slice = np.zeros(n_of_slices)

# fig = plt.figure(figsize = (15, 5))
# ax = fig.add_subplot(111, projection='3d')
# ax.set_box_aspect( (5, 1, 1) )

sliced_modes_data = []

for i in range(n_of_slices): 

    indexes = (positions[:, slice_axis] >= i*slice_size) & (positions[:, slice_axis] < (i+1)*slice_size)
    sliced_points = positions[indexes, :]
    sliced_modes_data += [modes[indexes, :]]
    particles_per_slice[i] =sliced_points.shape[0]
    
    temperatures[indexes] = T_array[i]
    
occupation = 1/( np.exp( ct.hbar*frequencies/(ct.k*temperatures) ) - 1)
energies = ct.hbar*frequencies*(occupation+0.5)

indexes = np.arange( n_of_particles )#((modes[:,0] == 0) & (modes[:,1] == 0)) | ((modes[:,0] == 0) & (modes[:,1] == 15))
points = positions[indexes, :]

fig = plt.figure(figsize = (15, 15))

ax = fig.add_subplot(221, projection='3d')
ax.set_box_aspect( np.ptp(limits, axis = 0) )
colors = frequencies[indexes]
graph = ax.scatter(points[:,0], points[:,1], points[:,2], c = colors, cmap = 'viridis', s = 2 )
fig.colorbar(graph, orientation = 'horizontal')
ax.set_title('Frequencies [rad/s]')


ax = fig.add_subplot(222, projection='3d')
ax.set_box_aspect( np.ptp(limits, axis = 0) )
colors = temperatures[indexes]
graph = ax.scatter(points[:,0], points[:,1], points[:,2], c = colors, cmap = 'viridis', s = 2 )
fig.colorbar(graph, orientation = 'horizontal')
ax.set_title('Temperatures [K]')

ax = fig.add_subplot(223, projection='3d')
ax.set_box_aspect( np.ptp(limits, axis = 0) )
colors = energies[indexes]
graph = ax.scatter(points[:,0], points[:,1], points[:,2], c = colors, cmap = 'viridis', s = 2 )
fig.colorbar(graph, orientation = 'horizontal')
ax.set_title('Energies [J]')

ax = fig.add_subplot(224, projection='3d')
ax.set_box_aspect( np.ptp(limits, axis = 0) )
colors = np.log(occupation[indexes])
graph = ax.scatter(points[:,0], points[:,1], points[:,2], c = colors, cmap = 'viridis', s = 2 )
fig.colorbar(graph, orientation = 'horizontal')
ax.set_title('Occupation number')

# plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0.92, 'Occupation number')

# %%
# HISTOGRAMS

fig = plt.figure(figsize = (15, 10))

# ax = fig.add_subplot(121)
# ax.bar(np.arange(n_of_slices), particles_per_slice)
# ax.set_title('Particles per slice.')
# ax.set_xlabel('Slice')

bins_data = []

for i in range(n_of_slices):
    data = sliced_modes_data[i]
    ax = fig.add_subplot(3, 4, i+1)
    bins, _, _, _ = ax.hist2d(data[:,1], data[:,0], bins = [n_of_branches, n_of_qpoints])
    ax.set_title('Particles per mode, slice {:>d} \n {:>d} particles, mean = {:.2f}, stdev = {:.2f}'.format(i, data.shape[0], data.mean(), data.std()),
                 fontsize = 10)
    ax.set_xlabel('Q-point')
    ax.set_ylabel('Branch')
    print( '{:>6d} particles; Mean particles per mode = {:>5.2f}; Std dev = {:>5.2f}; Max = {:>d}; Min = {:>d} '.format(data.shape[0], bins.mean(), bins.std(), bins.max().astype(int), bins.min().astype(int) ) )
    bins_data += [bins]

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 100126 particles; Mean particles per mode = 31.61; Std dev =  5.43; Max = 56; Min = 12
#  99714 particles; Mean particles per mode = 31.48; Std dev =  5.30; Max = 50; Min = 15
# 100370 particles; Mean particles per mode = 31.68; Std dev =  5.24; Max = 50; Min = 16
#  99630 particles; Mean particles per mode = 31.45; Std dev =  5.26; Max = 51; Min = 15
#  99700 particles; Mean particles per mode = 31.47; Std dev =  5.25; Max = 49; Min = 12
#  99707 particles; Mean particles per mode = 31.47; Std dev =  5.27; Max = 51; Min = 14
# 100576 particles; Mean particles per mode = 31.75; Std dev =  5.28; Max = 57; Min = 13
#  99403 particles; Mean particles per mode = 31.38; Std dev =  5.28; Max = 52; Min = 16
# 100129 particles; Mean particles per mode = 31.61; Std dev =  5.36; Max = 51; Min = 14
# 100645 particles; Mean particles per mode = 31.77; Std dev =  5.33; Max = 51; Min = 16

# %%
bins_data = [i.reshape(-1) for i in bins_data]

fig = plt.figure(figsize = (8, 5))
ax = fig.add_subplot(111)
ax.boxplot(bins_data, whis = 'range')
ax.set_xlabel('Slice')
ax.set_ylabel('Mode incidence')
ax.set_yticks(np.arange(6)*10+10)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# CALCULATING AVERAGES

energy_array = np.zeros(T_array.shape)
en_std_array = np.zeros(T_array.shape)
sliced_data = []

for i in range(n_of_slices):
    indexes = (positions[:, slice_axis] >= i*slice_size) & (positions[:, slice_axis] < (i+1)*slice_size)
    
    sliced_energies = energies[indexes]
    energy_array[i]  = sliced_energies.mean()   # average energy per particle
    en_std_array[i]  = sliced_energies.std()
    
    sliced_occupation = occupation[indexes]

    sliced_data += [sliced_occupation]

slice_array = np.arange(0, n_of_slices)

fig = plt.figure(figsize = (10, 5))
ax = fig.add_subplot(121)
# ax.boxplot(sliced_data, flierprops = {'marker': '.', 'markersize': 1, 'color': 'r'}, positions = slice_array )
ax.plot(slice_array, energy_array)
ax.set_title('Average energy per particle [J]')
ax.set_xlabel('Slice')
ax.set_xticks(np.arange(0, n_of_slices, 2))

ax = fig.add_subplot(122)
ax.plot(slice_array, T_array, '+', color = 'k', markersize = 10)

T_array_calc = temperature_function(energy_array)
ax.plot(slice_array, T_array_calc, '--')
ax.set_title('Average temperature [K]')
ax.set_xlabel('Slice')
ax.set_xticks(np.arange(0, n_of_slices, 2))
ax.legend(labels = ['T prescribed', 'T calculated'])

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# DRIFT OPERATION

dt = 0.01

start = time.time()

new_positions = positions+velocities*dt

end = time.time()

print('Drift done! Time = {:>.3f} s'.format(end-start))

start = time.time()

in_points = mesh.contains(new_positions)

end = time.time()

print('Check inside done! Time = {:>.3f} s'.format(end-start))

start = time.time()

new_positions = np.delete(new_positions, ~in_points, axis = 0)

end = time.time()

print('Delete out points done! Time = {:>.3f} s'.format(end-start))

start = time.time()

for i in range(n_of_slices): 

    indexes = (positions[:, slice_axis] >= i*slice_size) & (positions[:, slice_axis] < (i+1)*slice_size)
    energy_array[i] = energies[indexes].mean()

T_array_calc = temperature_function(energy_array)

end = time.time()

print('Updated energies and temperatures done! Time = {:>.3f} s'.format(end-start))
